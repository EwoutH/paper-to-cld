# %%
# Load and explore the paper_analysis_results.feather dataframe
import pandas as pd
df = pd.read_feather("results/paper_analysis_results_structured.feather")
df
# Out:
#                                  paper_metadata_title  \
# 0   Environmental impacts of autonomous vehicles: ...
# 1   Autonomous vehicles and employment: An urban f...
# 2   Impact of Driverless Vehicles on Urban Environ...
# 3   Autonomous Vehicles: An Analysis Both on Their...
# 4   Autonomous automobilities: The social impacts ...
# 5   A Review on Autonomous Vehicles: Progress, Met...
# 6   The Influence of Introducing Autonomous Vehicl...
# 7   Factors Influencing the Adoption of Shared Aut...
# 8   Impacts of Autonomous Vehicles on Greenhouse G...
# 9                       Safety of Autonomous Vehicles
# 10  Autonomous Vehicles and Intelligent Automation...
# 11              Autonomous Vehicles and Public Health
# 12  Residential Location Choice in the Era of Shar...
# 13  Autonomous vehicles in mixed motorway traffic:...
# 14  The Future of Transportation: Ethical, Legal, ...
# 15  Exploring the implications of autonomous vehic...
# ...
